# %% [markdown]
# # Loading Libraries

# %%
import numpy as np # to calculate
import pandas as pd # to read data
import matplotlib.pyplot as plt # to visualize data

# %% [markdown]
# # Loading Data

# %%
boston_data = pd.read_csv('Training_set_boston.csv')

# %% [markdown]
# # View Data

# %%
boston_data.head()
# Out:
#        CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 0  15.02340   0.0  18.10   0.0  0.6140  5.304  97.3  2.1007  24.0  666.0
# 1   0.62739   0.0   8.14   0.0  0.5380  5.834  56.5  4.4986   4.0  307.0
# 2   0.03466  35.0   6.06   0.0  0.4379  6.031  23.3  6.6407   1.0  304.0
# 3   7.05042   0.0  18.10   0.0  0.6140  6.103  85.1  2.0218  24.0  666.0
# 4   0.72580   0.0   8.14   0.0  0.5380  5.727  69.5  3.7965   4.0  307.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     20.2  349.48  24.91  12.0
# 1     21.0  395.62   8.47  19.9
# 2     16.9  362.25   7.83  19.4
# 3     20.2    2.52  23.29  13.4
# 4     21.0  390.95  11.28  18.2

# %% [markdown]
# # Separating Input Featues & Output Features

# %%
x = boston_data.drop('MEDV', axis=1)#Input Variable or Features
y = boston_data['MEDV']#Output Variable or Features

# %% [markdown]
# # Splitting the data

# %%
from sklearn.model_selection import train_test_split

#Assign variable to capture train_test_split output
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# x_train: independent/input feature data for training the model
# y_train: dependent/output feature data for training the model
# x_test: independent/input feature data for testing the model, will be used to predict the output values
# y_test: original dependent/output value of x_test, we will compare this value with predicted values to check the performances of our built model.
# test_size: 0.20: 20% of data go for test set & 80% data go for train set
# random_state: 42: this will fix the split, there will be same split for each time you run the code

# %%
#find the no of input features
n_features = x.shape[1]
print(n_features)
# Out:
# 13

# %% [markdown]
# # The 5 Step Model Life Cycle

# %% [markdown]
# # 1. Define the model

# %%
from tensorflow.keras import Sequential # import sequential from tensorflow.keras
from keras.layers import Dense, Activation # import Dense from tensorflow.keras.layers
from numpy.random import seed # seed helps to fix the randomness in the neural network
import tensorflow

# %%
# define the model
model = Sequential()
model.add(Dense(10, activation='tanh', input_shape=(n_features,)))
model.add(Dense(8, activation='tanh'))
model.add(Dense(1))

# %% [markdown]
# # 2. Compile the model

# %%
#import rmsProp optimizer
from tensorflow.keras.optimizers import RMSprop
optimizer = RMSprop(0.01)

# %%
model.compile(optimizer=optimizer, loss='mean_squared_error') # compile the model

# %% [markdown]
# # 3. Fitting the model

# %%
seed_value = 42
seed(seed_value) # If you build the model with given parameters, set_random_seed will produce the same result on mutiple execution.

import os
os.environ['PYTHONHASSEED']=str(seed_value)

import random
random.seed(seed_value)

import numpy as np
np.random.seed(seed_value)

tensorflow.random.set_seed(seed_value)

model.fit(x_train,y_train,batch_size=30, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 0s 980us/step - loss: 509.0151
# Epoch 2/10
# 11/11 [==============================] - 0s 718us/step - loss: 420.2433
# Epoch 3/10
# 11/11 [==============================] - 0s 492us/step - loss: 376.1070
# Epoch 4/10
# 11/11 [==============================] - 0s 687us/step - loss: 342.4167
# Epoch 5/10
# 11/11 [==============================] - 0s 729us/step - loss: 312.5908
# Epoch 6/10
# 11/11 [==============================] - 0s 558us/step - loss: 284.9698
# Epoch 7/10
# 11/11 [==============================] - 0s 756us/step - loss: 259.5948
# Epoch 8/10
# 11/11 [==============================] - 0s 841us/step - loss: 236.4520
# Epoch 9/10
# 11/11 [==============================] - 0s 543us/step - loss: 215.1021
# Epoch 10/10
# 11/11 [==============================] - 0s 646us/step - loss: 195.5335

# %% [markdown]
# # Evaluate the model

# %%
model.evaluate(x_test,y_test)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 166.6276
# 166.62762451171875

# %%
############## complete example to check the performance of the model with different learning rate
# define the model

model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(n_features,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))
          
optimizer = RMSprop(0.1) # 0.1 is learning_rate
model.compile( optimizer=optimizer, loss='mean_squared_error') # compile the model

#fit the model          
model.fit(x_train,y_train,batch_size=30, epochs=10, verbose=1)
          
#evaluate the model
print('The MSE value is:', model.evaluate(x_test,y_test))
# Out:
# Epoch 1/10
# 11/11 [==============================] - 0s 2ms/step - loss: 35268.1836
# Epoch 2/10
# 11/11 [==============================] - 0s 2ms/step - loss: 559.4070
# Epoch 3/10
# 11/11 [==============================] - 0s 827us/step - loss: 212.1510
# Epoch 4/10
# 11/11 [==============================] - 0s 731us/step - loss: 139.3775
# Epoch 5/10
# 11/11 [==============================] - 0s 1ms/step - loss: 129.5609
# Epoch 6/10
# 11/11 [==============================] - 0s 1ms/step - loss: 122.8495
# Epoch 7/10
# 11/11 [==============================] - 0s 876us/step - loss: 174.4107
# Epoch 8/10
# 11/11 [==============================] - 0s 1ms/step - loss: 142.8209
# Epoch 9/10
# 11/11 [==============================] - 0s 2ms/step - loss: 201.2061
# Epoch 10/10
# 11/11 [==============================] - 0s 1ms/step - loss: 224.0068
# 3/3 [==============================] - 0s 5ms/step - loss: 122.8435
# The MSE value is: 122.843505859375

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Test several learning rate values to see the impact of varying this value while defining your model.

# %%
#play with learning_rate

learning_rate = 0.001
epochs = 10
optimizer = RMSprop(learning_rate)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.fit(x_train, y_train, batch_size=30, epochs=epochs, verbose=1)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 0s 1ms/step - loss: 138.9598
# Epoch 2/10
# 11/11 [==============================] - 0s 781us/step - loss: 136.1004
# Epoch 3/10
# 11/11 [==============================] - 0s 502us/step - loss: 133.5800
# Epoch 4/10
# 11/11 [==============================] - 0s 731us/step - loss: 131.2986
# Epoch 5/10
# 11/11 [==============================] - 0s 773us/step - loss: 129.0988
# Epoch 6/10
# 11/11 [==============================] - 0s 446us/step - loss: 126.8422
# Epoch 7/10
# 11/11 [==============================] - 0s 743us/step - loss: 124.3310
# Epoch 8/10
# 11/11 [==============================] - 0s 586us/step - loss: 120.8165
# Epoch 9/10
# 11/11 [==============================] - 0s 2ms/step - loss: 116.6651
# Epoch 10/10
# 11/11 [==============================] - 0s 738us/step - loss: 111.1367
# 3/3 [==============================] - 0s 6ms/step - loss: 80.2539
# 80.25389862060547

# %% [markdown]
# # Epochs

# %%
#################### Complete the model to check the performance of the model with different epochs and learning rate = 0.01
# define the model

model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(n_features,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))

optimizer = RMSprop(0.01) # 0.01 is learning_rate
model.compile(optimizer=optimizer, loss='mean_squared_error') # compile the model

#fit the model
model.fit(x_train, y_train, batch_size=30, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 0s 2ms/step - loss: 244.1495
# Epoch 2/100
# 11/11 [==============================] - 0s 2ms/step - loss: 73.8451
# Epoch 3/100
# 11/11 [==============================] - 0s 2ms/step - loss: 75.9672
# Epoch 4/100
# 11/11 [==============================] - 0s 5ms/step - loss: 75.7670
# Epoch 5/100
# 11/11 [==============================] - 0s 3ms/step - loss: 65.8919
# Epoch 6/100
# 11/11 [==============================] - 0s 2ms/step - loss: 73.1731
# Epoch 7/100
# 11/11 [==============================] - 0s 2ms/step - loss: 63.1237
# Epoch 8/100
# 11/11 [==============================] - 0s 2ms/step - loss: 72.2858
# Epoch 9/100
# 11/11 [==============================] - 0s 2ms/step - loss: 67.9203
# Epoch 10/100
# 11/11 [==============================] - 0s 2ms/step - loss: 70.5173
# Epoch 11/100
# 11/11 [==============================] - 0s 2ms/step - loss: 66.0854
# Epoch 12/100
# 11/11 [==============================] - 0s 2ms/step - loss: 68.0845
# Epoch 13/100
# 11/11 [==============================] - 0s 2ms/step - loss: 56.7664
# Epoch 14/100
# 11/11 [==============================] - 0s 2ms/step - loss: 62.3643
# Epoch 15/100
# 11/11 [==============================] - 0s 2ms/step - loss: 65.8970
# Epoch 16/100
# 11/11 [==============================] - 0s 2ms/step - loss: 58.3881
# Epoch 17/100
# 11/11 [==============================] - 0s 2ms/step - loss: 56.6143
# Epoch 18/100
# 11/11 [==============================] - 0s 1ms/step - loss: 58.4851
# Epoch 19/100
# 11/11 [==============================] - 0s 2ms/step - loss: 62.7720
# Epoch 20/100
# 11/11 [==============================] - 0s 2ms/step - loss: 50.8161
# Epoch 21/100
# 11/11 [==============================] - 0s 2ms/step - loss: 58.9048
# Epoch 22/100
# 11/11 [==============================] - 0s 2ms/step - loss: 50.2541
# Epoch 23/100
# 11/11 [==============================] - 0s 2ms/step - loss: 58.3087
# Epoch 24/100
# 11/11 [==============================] - 0s 2ms/step - loss: 54.1072
# Epoch 25/100
# 11/11 [==============================] - 0s 2ms/step - loss: 54.8963
# Epoch 26/100
# 11/11 [==============================] - 0s 2ms/step - loss: 48.4042
# Epoch 27/100
# 11/11 [==============================] - 0s 3ms/step - loss: 47.0680
# Epoch 28/100
# 11/11 [==============================] - 0s 2ms/step - loss: 63.9644
# Epoch 29/100
# 11/11 [==============================] - 0s 2ms/step - loss: 40.5152
# Epoch 30/100
# 11/11 [==============================] - 0s 2ms/step - loss: 22.2923
# Epoch 68/100
# 11/11 [==============================] - 0s 1ms/step - loss: 34.4184
# Epoch 69/100
# 11/11 [==============================] - 0s 1ms/step - loss: 30.9435
# Epoch 70/100
# 11/11 [==============================] - 0s 2ms/step - loss: 31.3822
# Epoch 71/100
# 11/11 [==============================] - 0s 1ms/step - loss: 32.7467
# Epoch 72/100
# 11/11 [==============================] - 0s 1ms/step - loss: 34.8611
# Epoch 73/100
# 11/11 [==============================] - 0s 1ms/step - loss: 26.1480
# Epoch 74/100
# 11/11 [==============================] - 0s 1ms/step - loss: 36.3069
# Epoch 75/100
# 11/11 [==============================] - 0s 1ms/step - loss: 30.3239
# Epoch 76/100
# 11/11 [==============================] - 0s 1ms/step - loss: 28.8662
# Epoch 77/100
# 11/11 [==============================] - 0s 1ms/step - loss: 32.6670
# Epoch 78/100
# 11/11 [==============================] - 0s 2ms/step - loss: 33.0839
# Epoch 79/100
# 11/11 [==============================] - 0s 1ms/step - loss: 28.5567
# Epoch 80/100
# 11/11 [==============================] - 0s 2ms/step - loss: 23.9117
# Epoch 81/100
# 11/11 [==============================] - 0s 1ms/step - loss: 31.5906
# Epoch 82/100
# 11/11 [==============================] - 0s 2ms/step - loss: 23.7451
# Epoch 83/100
# 11/11 [==============================] - 0s 2ms/step - loss: 33.1853
# Epoch 84/100
# 11/11 [==============================] - 0s 1ms/step - loss: 31.5831
# Epoch 85/100
# 11/11 [==============================] - 0s 1ms/step - loss: 24.5399
# Epoch 86/100
# 11/11 [==============================] - 0s 1ms/step - loss: 28.2641
# Epoch 87/100
# 11/11 [==============================] - 0s 2ms/step - loss: 36.4226
# Epoch 88/100
# 11/11 [==============================] - 0s 1ms/step - loss: 24.8888
# Epoch 89/100
# 11/11 [==============================] - 0s 2ms/step - loss: 35.5705
# Epoch 90/100
# 11/11 [==============================] - 0s 1ms/step - loss: 29.8854
# Epoch 91/100
# 11/11 [==============================] - 0s 1ms/step - loss: 25.4877
# Epoch 92/100
# 11/11 [==============================] - 0s 1ms/step - loss: 41.1422
# Epoch 93/100
# 11/11 [==============================] - 0s 2ms/step - loss: 22.2564
# Epoch 94/100
# 11/11 [==============================] - 0s 2ms/step - loss: 28.1693
# Epoch 95/100
# 11/11 [==============================] - 0s 2ms/step - loss: 34.7894
# Epoch 96/100
# 11/11 [==============================] - 0s 1ms/step - loss: 22.1831
# Epoch 97/100
# 11/11 [==============================] - 0s 1ms/step - loss: 33.2569
# Epoch 98/100
# 11/11 [==============================] - 0s 1ms/step - loss: 29.4709
# Epoch 99/100
# 11/11 [==============================] - 0s 1ms/step - loss: 26.4330
# Epoch 100/100
# 11/11 [==============================] - 0s 1ms/step - loss: 29.6716

# %% [markdown]
# # Excercise 2

# %% [markdown]
# Test several epochs to see the impact of varying this value when defining the model.

# %%
# play with epochs
learning_rate = 0.01
epochs = 20
optimizer = RMSprop(learning_rate)
model.compile(optimizer=optimizer, loss='mean_squared_error') # compile the model
model.fit(x_train, y_train,  batch_size=30, epochs=epochs, verbose=1) # fit the model
model.evaluate(x_test,y_test) # evaluate the model
# Out:
# Epoch 1/20
# 11/11 [==============================] - 0s 3ms/step - loss: 61.1235
# Epoch 2/20
# 11/11 [==============================] - 0s 2ms/step - loss: 24.5448
# Epoch 3/20
# 11/11 [==============================] - 0s 2ms/step - loss: 28.9123
# Epoch 4/20
# 11/11 [==============================] - 0s 2ms/step - loss: 28.6976
# Epoch 5/20
# 11/11 [==============================] - 0s 2ms/step - loss: 24.6210
# Epoch 6/20
# 11/11 [==============================] - 0s 2ms/step - loss: 22.4767
# Epoch 7/20
# 11/11 [==============================] - 0s 2ms/step - loss: 28.2218
# Epoch 8/20
# 11/11 [==============================] - 0s 2ms/step - loss: 31.2385
# Epoch 9/20
# 11/11 [==============================] - 0s 2ms/step - loss: 25.9705
# Epoch 10/20
# 11/11 [==============================] - 0s 2ms/step - loss: 26.7888
# Epoch 11/20
# 11/11 [==============================] - 0s 2ms/step - loss: 24.6631
# Epoch 12/20
# 11/11 [==============================] - 0s 1ms/step - loss: 35.8650
# Epoch 13/20
# 11/11 [==============================] - 0s 2ms/step - loss: 24.5136
# Epoch 14/20
# 11/11 [==============================] - 0s 2ms/step - loss: 26.4975
# Epoch 15/20
# 11/11 [==============================] - 0s 1ms/step - loss: 32.0621
# Epoch 16/20
# 11/11 [==============================] - 0s 2ms/step - loss: 26.5286
# Epoch 17/20
# 11/11 [==============================] - 0s 2ms/step - loss: 34.6626
# Epoch 18/20
# 11/11 [==============================] - 0s 2ms/step - loss: 23.1626
# Epoch 19/20
# 11/11 [==============================] - 0s 2ms/step - loss: 29.3746
# Epoch 20/20
# 11/11 [==============================] - 0s 2ms/step - loss: 33.2515
# 3/3 [==============================] - 0s 2ms/step - loss: 17.7258
# 17.725797653198242

# %% [markdown]
# # Exercise 3

# %% [markdown]
# Find the best possible combination of learning rate and epochs while testing some combinations

# %%
# play with learning rate and epochs
learning_rate = 0.01
epochs = 30
optimizer = RMSprop(learning_rate)
model.compile(optimizer=optimizer, loss='mean_squared_error') # compile the model
model.fit(x_train, y_train, batch_size=30, epochs=epochs, verbose=1) # fit the model
model.evaluate(x_test, y_test) # evaluate the model
# Out:
# Epoch 1/30
# 11/11 [==============================] - 0s 3ms/step - loss: 47.7656
# Epoch 2/30
# 11/11 [==============================] - 0s 2ms/step - loss: 30.6350
# Epoch 3/30
# 11/11 [==============================] - 0s 2ms/step - loss: 33.8381
# Epoch 4/30
# 11/11 [==============================] - 0s 2ms/step - loss: 30.4014
# Epoch 5/30
# 11/11 [==============================] - 0s 2ms/step - loss: 23.6936
# Epoch 6/30
# 11/11 [==============================] - 0s 2ms/step - loss: 25.6223
# Epoch 7/30
# 11/11 [==============================] - 0s 1ms/step - loss: 28.8707
# Epoch 8/30
# 11/11 [==============================] - 0s 2ms/step - loss: 18.7767
# Epoch 9/30
# 11/11 [==============================] - 0s 2ms/step - loss: 29.9390
# Epoch 10/30
# 11/11 [==============================] - 0s 2ms/step - loss: 24.9697
# Epoch 11/30
# 11/11 [==============================] - 0s 2ms/step - loss: 26.8640
# Epoch 12/30
# 11/11 [==============================] - 0s 2ms/step - loss: 33.8399
# Epoch 13/30
# 11/11 [==============================] - 0s 2ms/step - loss: 24.5840
# Epoch 14/30
# 11/11 [==============================] - 0s 2ms/step - loss: 28.5658
# Epoch 15/30
# 11/11 [==============================] - 0s 2ms/step - loss: 28.0280
# Epoch 16/30
# 11/11 [==============================] - 0s 2ms/step - loss: 25.2833
# Epoch 17/30
# 11/11 [==============================] - 0s 2ms/step - loss: 32.8409
# Epoch 18/30
# 11/11 [==============================] - 0s 2ms/step - loss: 19.9366
# Epoch 19/30
# 11/11 [==============================] - 0s 1ms/step - loss: 28.9843
# Epoch 20/30
# 11/11 [==============================] - 0s 2ms/step - loss: 31.7619
# Epoch 21/30
# 11/11 [==============================] - 0s 2ms/step - loss: 22.8454
# Epoch 22/30
# 11/11 [==============================] - 0s 2ms/step - loss: 22.0944
# Epoch 23/30
# 11/11 [==============================] - 0s 2ms/step - loss: 34.5115
# Epoch 24/30
# 11/11 [==============================] - 0s 2ms/step - loss: 24.2633
# Epoch 25/30
# 11/11 [==============================] - 0s 2ms/step - loss: 22.5156
# Epoch 26/30
# 11/11 [==============================] - 0s 2ms/step - loss: 21.3918
# Epoch 27/30
# 11/11 [==============================] - 0s 2ms/step - loss: 29.0369
# Epoch 28/30
# 11/11 [==============================] - 0s 2ms/step - loss: 33.0116
# Epoch 29/30
# 11/11 [==============================] - 0s 2ms/step - loss: 23.4497
# Epoch 30/30
# 11/11 [==============================] - 0s 2ms/step - loss: 29.5665
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x0000026D044F39D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 2ms/step - loss: 15.9421
# 15.942070960998535

# %% [markdown]
# # Batch Size

# %% [markdown]
# The number of examples in a batch

# %%
##################### Complete example to check the performance of the model with different batch size while keeping epochs as 10 and learning rate 0.01
# define the model

model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(n_features,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))

optimizer = RMSprop(0.01) # 0.01 is the learning rate
model.compile(optimizer=optimizer, loss='mean_squared_error') # compile the model

#fit the model
model.fit(x_train, y_train, batch_size=30, epochs=10, verbose=1)

#evaluate the model
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 0s 2ms/step - loss: 285.7018
# Epoch 2/10
# 11/11 [==============================] - 0s 2ms/step - loss: 122.9754
# Epoch 3/10
# 11/11 [==============================] - 0s 2ms/step - loss: 135.3243
# Epoch 4/10
# 11/11 [==============================] - 0s 2ms/step - loss: 151.6190
# Epoch 5/10
# 11/11 [==============================] - 0s 2ms/step - loss: 108.8942
# Epoch 6/10
# 11/11 [==============================] - 0s 2ms/step - loss: 116.3931
# Epoch 7/10
# 11/11 [==============================] - 0s 2ms/step - loss: 96.5560
# Epoch 8/10
# 11/11 [==============================] - 0s 2ms/step - loss: 98.5671
# Epoch 9/10
# 11/11 [==============================] - 0s 2ms/step - loss: 107.1982
# Epoch 10/10
# 11/11 [==============================] - 0s 2ms/step - loss: 106.4254
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x0000026D045EF9D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 4ms/step - loss: 49.0354
# 49.03541946411133

# %% [markdown]
# # Exercise 4

# %% [markdown]
# Test several batch size values to see the impact of varying this value when defining your model

# %%
# play with batch size
learning_rate = 0.01
epochs = 150
batch = 40
optimizer = RMSprop(learning_rate)
model.compile(optimizer=optimizer, loss='mean_squared_error') # compile the model
model.fit(x_train, y_train, batch_size=batch, epochs=epochs, verbose=1) # fit the model
model.evaluate(x_test, y_test) # evaluate the model
# Out:
# Epoch 1/150
# 9/9 [==============================] - 0s 3ms/step - loss: 190.8502
# Epoch 2/150
# 9/9 [==============================] - 0s 2ms/step - loss: 59.4948
# Epoch 3/150
# 9/9 [==============================] - 0s 2ms/step - loss: 128.9224
# Epoch 4/150
# 9/9 [==============================] - 0s 2ms/step - loss: 68.7699
# Epoch 5/150
# 9/9 [==============================] - 0s 2ms/step - loss: 108.9144
# Epoch 6/150
# 9/9 [==============================] - 0s 2ms/step - loss: 80.1480
# Epoch 7/150
# 9/9 [==============================] - 0s 2ms/step - loss: 68.5309
# Epoch 8/150
# 9/9 [==============================] - 0s 2ms/step - loss: 78.6186
# Epoch 9/150
# 9/9 [==============================] - 0s 2ms/step - loss: 70.0486
# Epoch 10/150
# 9/9 [==============================] - 0s 2ms/step - loss: 64.2343
# Epoch 11/150
# 9/9 [==============================] - 0s 2ms/step - loss: 85.4643
# Epoch 12/150
# 9/9 [==============================] - 0s 2ms/step - loss: 78.0393
# Epoch 13/150
# 9/9 [==============================] - 0s 2ms/step - loss: 55.4422
# Epoch 14/150
# 9/9 [==============================] - 0s 2ms/step - loss: 103.9343
# Epoch 15/150
# 9/9 [==============================] - 0s 2ms/step - loss: 69.6744
# Epoch 16/150
# 9/9 [==============================] - 0s 2ms/step - loss: 64.0437
# Epoch 17/150
# 9/9 [==============================] - 0s 2ms/step - loss: 60.5503
# Epoch 18/150
# 9/9 [==============================] - 0s 2ms/step - loss: 65.6232
# Epoch 19/150
# 9/9 [==============================] - 0s 2ms/step - loss: 70.1107
# Epoch 20/150
# 9/9 [==============================] - 0s 2ms/step - loss: 55.0071
# Epoch 21/150
# 9/9 [==============================] - 0s 2ms/step - loss: 65.0953
# Epoch 22/150
# 9/9 [==============================] - 0s 2ms/step - loss: 47.9272
# Epoch 23/150
# 9/9 [==============================] - 0s 2ms/step - loss: 82.9931
# Epoch 24/150
# 9/9 [==============================] - 0s 2ms/step - loss: 52.4051
# Epoch 25/150
# 9/9 [==============================] - 0s 2ms/step - loss: 68.9963
# Epoch 26/150
# 9/9 [==============================] - 0s 2ms/step - loss: 57.1801
# Epoch 27/150
# 9/9 [==============================] - 0s 2ms/step - loss: 61.3986
# Epoch 28/150
# 9/9 [==============================] - 0s 2ms/step - loss: 49.2633
# Epoch 29/150
# 9/9 [==============================] - 0s 2ms/step - loss: 52.7074
# Epoch 30/150
# 9/9 [==============================] - 0s 2ms/step - loss: 50.1401
# Epoch 31/150
# 9/9 [==============================] - 0s 2ms/step - loss: 48.1202
# Epoch 32/150
# 9/9 [==============================] - 0s 1ms/step - loss: 31.0296
# Epoch 145/150
# 9/9 [==============================] - 0s 1ms/step - loss: 28.3644
# Epoch 146/150
# 9/9 [==============================] - 0s 1ms/step - loss: 44.2597
# Epoch 147/150
# 9/9 [==============================] - 0s 1ms/step - loss: 28.1731
# Epoch 148/150
# 9/9 [==============================] - 0s 1ms/step - loss: 37.8629
# Epoch 149/150
# 9/9 [==============================] - 0s 1ms/step - loss: 40.2943
# Epoch 150/150
# 9/9 [==============================] - 0s 1ms/step - loss: 26.5535
# 3/3 [==============================] - 0s 3ms/step - loss: 29.7156
# 29.7155704498291

# %% [markdown]
# # Implementing hyperparameter tuning with sklearn

# %%
# Import the GridSearchCV class
from sklearn.model_selection import GridSearchCV

# 1. Define the model's architecture
model = Sequential()
model.add(Dense(10, activation='relu', input_shape= (n_features,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))

optimizer = RMSprop(0.01) # 0.01 is the learning_rate
model.compile(optimizer=optimizer, loss='mean_squared_error') # compile the model

# 2. Define the hyperparameters grid to be validated.
batch_size = [10, 20, 40, 60, 80, 100]
epochs = [10,50,100]
param_grid = dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_squared_error', n_jobs=-1)

# 3. Run the GridSearchCV process
grid_result = grid.fit(x_train, y_train)

# 4. Prints the best results of the model
print("Best : %f of using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7100/2398047877.py in <module>
#      18
#      19 # 3. Run the GridSearchCV process
# ---> 20 grid_result = grid.fit(x_train, y_train)
#      21
#      22 # 4. Prints the best results of the model
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     763         n_splits = cv_orig.get_n_splits(X, y, groups)
#     764
# --> 765         base_estimator = clone(self.estimator)
#     766
#     767         parallel = Parallel(n_jobs=self.n_jobs,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in clone(estimator, safe)
#      65                                 "scikit-learn estimator instead of a class.")
#      66             else:
# ---> 67                 raise TypeError("Cannot clone object '%s' (type %s): "
#      68                                 "it does not seem to be a scikit-learn "
#      69                                 "estimator as it does not implement a "
#
# TypeError: Cannot clone object '<keras.engine.sequential.Sequential object at 0x0000026D0572A340>' (type <class 'keras.engine.sequential.Sequential'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.

# %%
#----------------------Functional Tuning - option 1: Using sklearn ---------------------------
#----------------Tune the batch_size and epochs

# Import kerasRegressor Class
from keras.wrappers.scikit_learn import KerasRegressor

# Define the model through user-defined function
def create_model(optimizer=RMSprop(0.01)):
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_features,)))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

model = KerasRegressor(build_fn=create_model, verbose=1)

# Define the hyperparameters grid to be validated
batch_size = [10,20,30,40,60,80,100]
epochs = [10, 50, 100]
param_grid = dict(batch_size=batch_size, nb_epoch=epochs)
model = KerasRegressor(build_fn = create_model, verbose = 1)
grid = GridSearchCV(estimator=model, param_grid = param_grid, n_jobs=-1, cv=5)

# Run the GridSearchCV process
grid_result = grid.fit(x_train, y_train, verbose=1)

# Print the result of the best model
print('Best Params:' + str(grid_result.best_params_))
# Out:
# C:\Users\saman\AppData\Local\Temp/ipykernel_7100/882940866.py:17: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, verbose=1)
# C:\Users\saman\AppData\Local\Temp/ipykernel_7100/882940866.py:23: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn = create_model, verbose = 1)
# 33/33 [==============================] - 1s 1ms/step - loss: 109.4085
# Best Params:{'batch_size': 10, 'nb_epoch': 50}

# %%
#Import the cross validation evaluator
from sklearn.model_selection import cross_val_score

#Measure the model's performance
results = cross_val_score(grid.best_estimator_, x_test, y_test, cv=5)
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 1212.7388
# 2/2 [==============================] - 0s 6ms/step - loss: 459.0064
# 7/7 [==============================] - 0s 3ms/step - loss: 269.6880
# 2/2 [==============================] - 0s 3ms/step - loss: 83.5319
# 7/7 [==============================] - 0s 3ms/step - loss: 258.3931
# 2/2 [==============================] - 0s 5ms/step - loss: 347.2680
# 7/7 [==============================] - 0s 2ms/step - loss: 754.9720
# 2/2 [==============================] - 0s 4ms/step - loss: 202.7710
# 7/7 [==============================] - 0s 2ms/step - loss: 835.3890
# 2/2 [==============================] - 0s 8ms/step - loss: 88.5821

# %%
print('Results: \n * Mean:', -results.mean(), '\n * Std:', results.std())
# Out:
# Results:
#  * Mean: 236.23188171386718
#  * Std: 147.10193744137476

# %% [markdown]
# # Implementing Hyperparameter tuning with keras

# %%
#---------------------Functional Tuning - Option 2: using keras tuner ------------------------------
# Goal: Tune the learning rate

# Install and Import all packages needed
# !pip install -q -U keras-tuner

# %%
import keras_tuner as kt

# 1. Define the general architecture of the model through creating a user defined function

def model_builder(hp):
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_features,)))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1))
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-1, 1e-2, 1e-3, 1e-4]) # Tuning the learning rate for different values to test:
    0.1, 0.01, 0.001, 0.0001
    optimizer = RMSprop(learning_rate=hp_learning_rate) # Defining the optimizer
    model.compile(loss='mse', metrics=['mse'], optimizer = optimizer) # Compiling the model
    return model # Returning the defined model
# 2. Define the hyperparameter grid to be validated
tuner_rs = kt.RandomSearch(model_builder, # Takes hyperparameters(hp) and returns a model instance
                           objective='mse', # name of the model metric to minimize or maximize
                           seed=42, # random_seed for replication purposes
                           max_trials = 5, # Total no of trials 5 to test at most. Note that the oracle may interrupt the search before max trials have been tested.
                           directory = 'random_search') # Path to the working directory ( relative).

# 3. Run the GridSearchCV process
tuner_result = tuner_rs.search(x_train, y_train, epochs=10, validation_split=0.2, verbose=1 )
# Out:
# Trial 4 Complete [00h 00m 02s]
# mse: 105.93234252929688
#
# Best mse So Far: 78.80366516113281
# Total elapsed time: 00h 00m 14s
# INFO:tensorflow:Oracle triggered exit

# %%
# Print the summary results of hyperparameter tuning procedure
tuner_rs.results_summary()
# Out:
# Results summary
# Results in random_search\untitled_project
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000026D07D78EB0>
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# Score: 78.80366516113281
# Trial summary
# Hyperparameters:
# learning_rate: 0.1
# Score: 97.05403900146484
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# Score: 105.93234252929688
# Trial summary
# Hyperparameters:
# learning_rate: 0.001
# Score: 110.47988891601562

# %%
# Print the results of the best model
best_model = tuner_rs.get_best_models(num_models=1)[0]
best_model.evaluate(x_test, y_test)
# Out:
# 3/3 [==============================] - 0s 8ms/step - loss: 54.8566 - mse: 54.8566
# [54.85663986206055, 54.85663986206055]

# %%
# Print the best model's architecture
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                140
#
#  dense_1 (Dense)             (None, 8)                 88
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 237
# Trainable params: 237
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Load New Test Data
test_data = pd.read_csv('Testing_set_boston.csv')

# %%
# Make a prediction
best_model.predict(test_data)
# Out:
# 4/4 [==============================] - 0s 8ms/step
# array([[27.85613   ],
#        [28.098253  ],
#        [23.667978  ],
#        [23.481367  ],
#        [22.157389  ],
#        [24.344774  ],
#        [26.195288  ],
#        [24.942862  ],
#        [23.273943  ],
#        [26.216652  ],
#        [27.645197  ],
#        [26.740955  ],
#        [-2.0666065 ],
#        [24.140024  ],
#        [26.22043   ],
#        [20.896631  ],
#        [24.904507  ],
#        [18.598173  ],
#        [30.229355  ],
#        [22.34199   ],
#        [26.084349  ],
#        [27.701296  ],
#        [23.74471   ],
#        [26.626284  ],
#        [17.43672   ],
#        [19.183302  ],
#        [24.270977  ],
#        [ 3.3067722 ],
#        [26.992823  ],
#        [25.717934  ],
#        [27.604223  ],
#        [26.106539  ],
#        [20.760008  ],
#        [22.76365   ],
#        [18.25302   ],
#        [17.310175  ],
#        [27.124695  ],
#        [25.95061   ],
#        [24.933018  ],
#        [22.293993  ],
#        [25.248455  ],
#        [28.359991  ],
#        [30.087257  ],
#        [24.860182  ],
#        [26.898235  ],
#        [22.633074  ],
#        [24.048952  ],
#        [22.886662  ],
#        [22.756315  ],
#        [28.344706  ],
#        [27.661528  ],
#        [27.340889  ],
#        [26.593702  ],
#        [26.244474  ],
#        [28.093313  ],
#        [21.156279  ],
#        [23.246134  ],
#        [29.653822  ],
#        [26.20166   ],
#        [25.795694  ],
#        [26.30751   ],
#        [29.310703  ],
#        [23.896206  ],
#        [16.941391  ],
#        [25.142334  ],
#        [26.528418  ],
#        [22.314447  ],
#        [26.50341   ],
#        [28.961882  ],
#        [ 4.640951  ],
#        [25.155155  ],
#        [22.460863  ],
#        [ 8.563673  ],
#        [25.879625  ],
#        [24.059269  ],
#        [15.292818  ],
#        [26.51209   ],
#        [30.11196   ],
#        [20.899515  ],
#        [19.861624  ],
#        [25.04909   ],
#        [16.297728  ],
#        [27.8206    ],
#        [21.106703  ],
#        [27.58355   ],
#        [24.268192  ],
#        [13.023775  ],
#        [25.561146  ],
#        [26.716742  ],
#        [26.296124  ],
#        [25.740557  ],
#        [ 3.2427197 ],
#        [26.383911  ],
#        [22.579844  ],
#        [20.34854   ],
#        [25.818312  ],
#        [21.020645  ],
#        [ 0.25534052],
#        [ 3.2377586 ],
#        [ 2.2529068 ],
#        [25.748127  ],
#        [23.827448  ]], dtype=float32)
